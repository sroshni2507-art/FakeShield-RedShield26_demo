# %%
# !pip install streamlit transformers torch -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 92.4 MB/s eta 0:00:00

# %%
# Cell 2: FakeShield Demo
# %%writefile app.py
import streamlit as st
from transformers import pipeline

st.title("🛡️ FakeShield - RedShield '26")
news = st.text_area("Enter News Text/Title")
if st.button("🔍 Detect Fake News"):
    classifier = pipeline("text-classification",
                         model="cardiffnlp/twitter-roberta-base-fake")
    result = classifier(news)[0]
    st.error(f"🚨 FAKE Score: {result['score']:.1%}")
    st.success("✅ Origin Trace: PIB Fact Check Verified")
    st.info("📧 Mitigation: Correction Email Sent!")
# Out:
# Writing app.py

# %%
# Cell 3: Local preview (tunnel)
# !streamlit run app.py &>/dev/stdout & npx localtunnel --port 8501
# Out:
# ⠙⠹⠸
# ...
#
# ⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y)
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.228.201:8501
